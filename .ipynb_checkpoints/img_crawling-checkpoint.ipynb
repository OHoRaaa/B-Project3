# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common import keys
from selenium.webdriver.common.action_chains import ActionChains
import os, urllib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data_file/여행지 라벨.xlsx')
df.head(3)
# Out:
#     나라       관광지    en나라          en관광지   유형 Unnamed: 5
# 0  그리스      산토리니  Greece      Santorini  건축물        NaN
# 1   대만  타이베이 101  Taiwan     Taipei 101  건축물        NaN
# 2   대만       용산사  Taiwan  Taipei Temple  건축물         성지

# %%
datas = df[['en나라', 'en관광지']]

# %%
datas.values[2:]
# Out:
# array([['Taiwan', 'Taipei Temple'],
#        ['Germany', 'Neuschwanstein'],
#        ['Germany', 'Brandenburg Gate'],
#        ['Germany', 'Berliner Dom'],
#        ['Germany', 'Hamburg Town Hall'],
#        ['Germany', 'Cologne Cathedral'],
#        ['Germany', 'Rothenburg'],
#        ['Lebanon', 'Baalbek'],
#        ['Malaysia', 'Petronas Twin Tower'],
#        ['Malaysia', 'Penang temple'],
#        ['Mexico', 'Teotihuacan'],
#        ['Mexico', 'Chichen Itza'],
#        ['Marrakech', 'Koutoubia Mosque'],
#        [' America', 'Griffith Observatory'],
#        ['America', 'Statue of Liberty'],
#        ['Myanmar', 'Ananda Temple'],
#        ['Myanmar', 'Shwezigon'],
#        ['Myanmar', 'Dhammayangyi Temple'],
#        ['Myanmar', 'Shwedagon Pagoda'],
#        ['Brazil', 'Corcovado'],
#        ['Brazil', 'Escadaria Selaron'],
#        ['Saudi Arabia', 'Mecca'],
#        ['Spain', 'Sagrada Familia'],
#        ['Spain', 'Casa Batllo'],
#        ['Spain', 'Parc Guell'],
#        ['Spain', 'Cordoba Mezquita'],
#        ['Singapore', 'Gardens by the Bay'],
#        ['United Arab Emirates', 'Burj Khalifa'],
#        ['England', 'Stonehenge'],
#        ['England', 'Tower Bridge'],
#        ['England', "St. Paul's Cathedral"],
#        ['Jordan', 'Petra'],
#        ['Israel', 'Western Wall'],
#        ['Israel', 'Tower of David'],
#        ['Egypt', 'Temple of Karnak'],
#        ['Egypt', 'Colossi of Memnon'],
#        ['Egypt', 'Egypt Pyramid'],
#        ['Egypt', 'abu simbel'],
#        ['Italy', 'Colosseum'],
#        ['Italy', 'Trevi Fountain'],
#        ['Italy', 'Pantheon'],
#        ['Italy', 'Bocca della Verita'],
#        ['Italy', 'Arco di Costantino'],
#        ['Italy', 'Basilica di San Marco'],
#        ['Italy', 'Ponte di Rialto'],
#        ['Italy', 'Campanile di San Marco'],
#        ['Italy', 'Leaning Tower of Pisa'],
#        ['India', 'Gateway of India'],
#        ['India', 'Qutub Minar'],
#        ['India', 'Taj Mahal'],
#        ['India', 'Golden Temple'],
#        ['Indonesia', 'Borobudur'],
#        ['Japan', 'Osaka Castle'],
#        ['Japan', 'Kinkakuji Temple'],
#        ['China', 'Canton Tower'],
#        ['China', 'qin terracotta warriors'],
#        ['China', 'The Great Wall'],
#        ['China', 'Forbidden City'],
#        ['China', 'Potala Palace'],
#        ['Czech Republic', 'Staromestske namesti'],
#        ['Chile', 'Easter Island'],
#        ['Cambodia', 'Angkor Wat'],
#        ['Thailand', 'The Sanctuary Of Truth'],
#        ['Thailand', 'The Grand Palace'],
#        ['Thailand', 'Wat Arun'],
#        ['Thailand', 'Wat Phra Kaew'],
#        ['Turkey', 'Blue Mosque'],
#        ['Turkey', 'Basilica Cistern'],
#        ['Turkey', "Hadrian's Gate"],
#        ['Peru', 'Machu Picchu'],
#        ['France', 'Louvre Museum'],
#        ['France', 'Eiffel Tower'],
#        ['France', 'Cathedrale Notre-Dame de Paris'],
#        ['France', 'Arc de Triomphe'],
#        ['France', 'Sainte-Chapelle'],
#        ['France', 'Moulin Rouge'],
#        ['France', 'Hotel de Ville'],
#        ['Australia', 'Sydney Opera House']], dtype=object)

# %%
page_limit = 25
page_num = 50
max_count = page_limit * page_num

for data in datas.values:
    country = data[0]
    search_name = data[1]
    count = 0
    print(f"{search_name} downloading...", end=" ")
    for page in range(page_num):
        res = requests.get(f"https://stock.adobe.com/kr/search/images?filters%5Bcontent_type%3Aphoto%5D=1&filters%5Bcontent_type%3Aimage%5D=1&filters%5Breleases%3Ais_exclude%5D=1&k={search_name}&order=relevance&safe_search=1&search_type=usertyped&limit={page_limit - 1}&search_page={page}&acp=&aco={search_name}&get_facets=1")
        soup = BeautifulSoup(res.text, 'html.parser')
        div = soup.select('picture > source')
        for i, img in enumerate(div):
            url = img['srcset']
            if not os.path.exists(f"img/{country}"):
                os.makedirs(f"img/{country}")
            if not os.path.exists(f"img/{country}/{search_name}"):
                os.makedirs(f"img/{country}/{search_name}")
            if count <= (max_count * 0.6):
                if not os.path.exists(f"img/img_gen/train/{search_name}"):
                    os.makedirs(f"img/img_gen/train/{search_name}")
                urllib.request.urlretrieve(url, f"img/img_gen/train/{search_name}/{count}.jpg")
            elif count <= (max_count * 0.8):
                if not os.path.exists(f"img/img_gen/validataion/{search_name}"):
                    os.makedirs(f"img/img_gen/validataion/{search_name}")
                urllib.request.urlretrieve(url, f"img/img_gen/validataion/{search_name}/{count}.jpg")
            else:
                if not os.path.exists(f"img/img_gen/test/{search_name}"):
                    os.makedirs(f"img/img_gen/test/{search_name}")
                urllib.request.urlretrieve(url, f"img/img_gen/test/{search_name}/{count}.jpg")
            
            count += 1
            
    
    print(f"{count} download successful")
# Out:
# Santorini downloading... 1250 download successful
# Taipei 101 downloading... 1250 download successful
# Taipei Temple downloading... 1236 download successful
# Neuschwanstein downloading... 1250 download successful
# Brandenburg Gate downloading... 1250 download successful
# Berliner Dom downloading... 1250 download successful
# Hamburg Town Hall downloading... 1250 download successful
# Cologne Cathedral downloading... 1250 download successful
# Rothenburg downloading... 1250 download successful
# Baalbek downloading... 1224 download successful
# Petronas Twin Tower downloading... 1250 download successful
# Penang temple downloading... 1243 download successful
# Teotihuacan downloading... 1250 download successful
# Chichen Itza downloading... 1250 download successful
# Koutoubia Mosque downloading... 1250 download successful
# Griffith Observatory downloading... 1250 download successful
# Statue of Liberty downloading... 1250 download successful
# Ananda Temple downloading... 1237 download successful
# Shwezigon downloading... 1219 download successful
# Dhammayangyi Temple downloading... 1209 download successful
# Shwedagon Pagoda downloading... 1250 download successful
# Corcovado downloading... 1236 download successful
# Escadaria Selaron downloading... 1235 download successful
# Mecca downloading... 1250 download successful
# Sagrada Familia downloading... 1250 download successful
# Casa Batllo downloading... 1235 download successful
# Parc Guell downloading... 1240 download successful
# Cordoba Mezquita downloading... 1250 download successful
# Gardens by the Bay downloading... 1250 download successful
# Burj Khalifa downloading... 1250 download successful
# Stonehenge downloading...

# %%
df[df['나라'] == '중국']
# Out:
#     나라     관광지   en나라                    en관광지   유형 Unnamed: 5
# 56  중국  광저우 타워  China             Canton Tower  건축물       랜드마크
# 57  중국     병마용  China  qin terracotta warriors   유적       고대유적
# 58  중국    만리장성  China           The Great Wall   유적       고대유적
# 59  중국     자금성  China           Forbidden City  NaN        NaN
# 60  중국   포탈라 궁  China            Potala Palace  건축물        NaN

# %%
page_limit = 25
page_num = 5
crawling_num = 20

country = 'China'
search_name = 'qin terracotta warriors'
count = 0
for page in range(page_num):
    res = requests.get(f"https://stock.adobe.com/kr/search/images?filters%5Bcontent_type%3Aphoto%5D=1&filters%5Bcontent_type%3Aimage%5D=1&filters%5Breleases%3Ais_exclude%5D=1&k={search_name}&order=relevance&safe_search=1&search_type=usertyped&limit={page_limit - 1}&search_page={page}&acp=&aco={search_name}&get_facets=1")
    soup = BeautifulSoup(res.text, 'html.parser')
    div = soup.select('picture > source')[:20]
    for i, img in enumerate(div):
        url = img['srcset']
        if not os.path.exists(f"img/{country}"):
            os.makedirs(f"img/{country}")
        if not os.path.exists(f"img/{country}/{search_name}"):
            os.makedirs(f"img/{country}/{search_name}")
        urllib.request.urlretrieve(url, f"img/{country}/{search_name}/{count}.jpg")
        #print("download successful")
        count += 1
print('=' * 50)
print(country, count, 'download successful')
print('=' * 50)
# Out:
# ==================================================
# 100 download successful
# ==================================================
